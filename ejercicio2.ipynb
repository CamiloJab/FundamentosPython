# %%
num1 = 1
num2 = 3
if num1 == num2:
  print("son iguales")
else:
  print("no son iguales")
# Out:
# no son iguales

# %%
usuario = input("Digite su usuario")
usubd = "Carlos 123"

if usuario == usubd:
  print("Bienvenido !")
else:
  print("su usuario no se encuentra")
# Out:
# Digite su usuarioCarlos 124
# su usuario no se encuentra

# %%
num = int(input("Digite un numero: "))

if num > 20:
  print ("el numero es mayor a 20")
elif num > 15:
  print("el numero es mayor a 15")
elif num > 10:
  print("el numero es mayor a 10")
elif num > 5:
  print("el numero es mayor a 5")
else:
  print("no se cumple con la condicion")
# Out:
# Digite un numero: 4
# no se cumple con la condicion

# %%
edad = int(input("Digite su edad "))

if edad >= 13 and edad <20:
  print("Eres un adolecente")
else:
  print("No eres un adolecente")
# Out:
# Digite su edad 21
# No eres un adolecente

# %%
palabra = input("Digite una frase que quiera buscar: ")

if palabra in "lina catalina rami torres": #el indicador IN solo funciona con texto
  print("Verdadero")
else:
  print("Falso")
# Out:
# Digite una frase que quiera buscar: talina
# Verdadero

# %%
cal1 = float(inout("Digite su nota 1" ))
cal2 = float(inout("Digite su nota 2" ))
cal3 = float(inout("Digite su nota 3" ))

prom = round ((cal1 + cal2 + cal3)/3, 2) # ROUND para redondear, con el 2 se indica para saber cuantas decimales queremos, se separa con la ,

if prom < 3.0:
  estado ="reprobo"
else promo > 3.0:
  estado = "aprobo"

# %% [markdown]
# 1. Si el empleado es mayor de 55 años disfrutará de un bono de prepensión correspondiente al 5% de su sueldo básico.
#
# 2. Si el empleado es casado y tiene hijos se le otorgará un paseo cada diciembre
#
# 3. Si el sueldo básico está entre 1000000 y 1500000 tendrá una comisión del 2% sobre el valor del sueldo; Si el sueldo básico está entre 1500001 y 2000000 tendrá una comisión del 5% sobre el valor del sueldo; para todos los demás casos no habrá comisión.
#
# 4. Si el empleado trabajó más de 20 días al mes y su sueldo es menor a 1000000 tendrá derecho a un bono de alimentación.

# %%
print("Hola, por favor indique la informacion solicitada a continuacion para poder continuar")
#PerIdentificacion = input("Digite su cedula ")
#PerNombre = input("Digite se nombre ")
#PerApellido = input("Digite su apellido ")
#PerDireccion = input("Digite su direccion ")
#PerTelefono = input("Digite su telefono ")
PerEdad = int(input("Digite su edad "))
PerEstadocivil = str(input("Describa su estado civil "))
PerNumerohijos = int(input("Cuantos hijos tiene? (en numero) "))
#PerEstatura = input("Canta estatura tiene? (en metros)")
#PerContratacion = input("Indique su fecha de contratacion (día/mes/año) ")
PerSueldo = int(input("Indique su sueldo actual (solo numeros)"))
PerDiaslaborados = int(input("Cuantos días a la semana labora? "))

sueldoBono = ((PerSueldo*0.05)+PerSueldo)
comision1 = ((PerSueldo*0.02)+PerSueldo)
comision2 = ((PerSueldo*0.05)+PerSueldo)


#primer punto
if PerEdad > 55:
  print(f"\n Por ser mayor de 55 años tendra bono de prepension correspondiente a un valor de : {sueldoBono}")

#segundo punto
if PerNumerohijos >= 1 and "casad" in PerEstadocivil:
  print("\n\n Tiene derecho a un viaje cada diciembre")
else: 
  print("\n\n No tiene derecho a viajes por la empresa")

#tercer punto
if PerSueldo > 1000000 and PerSueldo < 1500000:
  print(f"\n\n Su comisión sera del 2% por valor de: {comision1}")
elif PerSueldo > 1500001:
  print(f"\n\n Su comisión sera del 5% por valor de: {comision2}")
else:
  print("\n\n No tiene derecho a comisión")

#cuarto punto
if PerDiaslaborados > 21 and PerSueldo < 1000000:
  print("\n\n Tiene derecho a bono de alimentación")
else:
  print("\n\n No tiene derecho a alimentacion")
# Out:
# Hola, por favor indique la informacion solicitada a continuacion para poder continuar
# Digite su edad 57
# Describa su estado civil casada
# Cuantos hijos tiene? (en numero) 3
# Indique su sueldo actual (solo numeros)1700000
# Cuantos días a la semana labora? 29
#
#  Por ser mayor de 55 años tendra bono de prepension correspondiente a un valor de : 1785000.0
#
#
#  Tiene derecho a un viaje cada diciembre
#
#
#  Su comisión sera del 5% por valor de: 1785000.0
#
#
#  No tiene derecho a alimentacion
